# %%
# r.text
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10966070747","type":"PushEvent","actor":{"id":40421053,"login":"Xuezenghuigithub","display_login":"Xuezenghuigithub","gravatar_id":"","url":"https://api.github.com/users/Xuezenghuigithub","avatar_url":"https://avatars.githubusercontent.com/u/40421053?"},"repo":{"id":220428352,"name":"Xuezenghuigithub/xuezenghui.com","url":"https://api.github.com/repos/Xuezenghuigithub/xuezenghui.com"},"payload":{"push_id":4330460801,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"a08abe5251d7f812185f0de9a9c7d2af3918213c","before":"c49f266a740efb475e29520212954e503545afdb","commits":[{"sha":"a08abe5251d7f812185f0de9a9c7d2af3918213c","author":{"email":"zander.xue@belstar.com.cn","name":"Zander Xue"},"message":"SementFault➡️SegmentFault","distinct":true,"url":"https://api.github.com/repos/Xuezenghuigithub/xuezenghui.com/commits/a08abe5251d7f812185f0de9a9c7d2af3918213c"}]},"public":true,"created_at":"2019-11-28T05:43:42Z"},{"id":"10966070745","type":"DeleteEvent","actor":{"id":73906
# ...

# %%
# json.loads
import json

json.loads(r.text)
# Out:
# [{'id': '10966070747',
#   'type': 'PushEvent',
#   'actor': {'id': 40421053,
#    'login': 'Xuezenghuigithub',
#    'display_login': 'Xuezenghuigithub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Xuezenghuigithub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40421053?'},
#   'repo': {'id': 220428352,
#    'name': 'Xuezenghuigithub/xuezenghui.com',
#    'url': 'https://api.github.com/repos/Xuezenghuigithub/xuezenghui.com'},
#   'payload': {'push_id': 4330460801,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'a08abe5251d7f812185f0de9a9c7d2af3918213c',
#    'before': 'c49f266a740efb475e29520212954e503545afdb',
#    'commits': [{'sha': 'a08abe5251d7f812185f0de9a9c7d2af3918213c',
#      'author': {'email': 'zander.xue@belstar.com.cn', 'name': 'Zander Xue'},
#      'message': 'SementFault➡️SegmentFault',
#      'distinct': True,
# ...

# %%
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容：r.text
r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '{"all":[{"_id":"5b4911940508220014ccfe94","text":"By the time a cat is 9 years old, it will only have been awake for three years of its life.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex","last":"Wohlbruck"}},"upvotes":5,"userUpvoted":null},{"_id":"58e008ad0aac31001185ed0c","text":"The frequency of a domestic cat\'s purr is the same at which muscles and bones repair themselves.","type":"cat","user":{"_id":"58e007480aac31001185ecef","name":{"first":"Kasimir","last":"Schulz"}},"upvotes":5,"userUpvoted":null},{"_id":"5955792c7b77520020799431","text":"Cats \\"knead\\" because of seperation from their mothers","type":"cat","user":{"_id":"595579027b77520020799430","name":{"first":"Is It Still Memes That","last":"Make You Sweat?"}},"upvotes":5,"userUpvoted":null},{"_id":"59a60b8e6acf530020f3586e","text":"Cat owners are 17% more likely to have a graduate degree than non cat owners.","type":"cat","user":{"_id":"5a9ac18c7478810ea6c06381","name":{"first":"Alex",
# ...

# %%
# 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容：json.loads
json.loads(r.text)
# Out:
# {'all': [{'_id': '5b4911940508220014ccfe94',
#    'text': 'By the time a cat is 9 years old, it will only have been awake for three years of its life.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '5955792c7b77520020799431',
#    'text': 'Cats "knead" because of seperation from their mothers',
#    'type': 'cat',
#    'user': {'_id': '595579027b77520020799430',
#     'name': {'first': 'Is It Still Memes That', 'last': 'Make You Sweat?'}},
#    'upvotes': 5,
#    'userUpvoted': None},
#   {'_id': '59a60b8e6acf530020f3586e',
# ...
